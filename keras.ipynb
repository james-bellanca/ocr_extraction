# %%
import sys
# !brew install openblas
# !{sys.executable} -m pip install keras-ocr
# Out:
# Warning: openblas 0.3.26 is already installed and up-to-date.
# To reinstall 0.3.26, run:
#   brew reinstall openblas
# Requirement already satisfied: keras-ocr in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.9.3)
# Requirement already satisfied: editdistance in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from keras-ocr) (0.8.1)
# Requirement already satisfied: efficientnet==1.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from keras-ocr) (1.0.0)
# Requirement already satisfied: essential_generators in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from keras-ocr) (1.0)
# Requirement already satisfied: fonttools in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from keras-ocr) (4.39.4)
# Requirement already satisfied: imgaug in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from keras-ocr) (0.4.0)
# Requirement already satisfied: pyclipper in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from keras-ocr) (1.3.0.post5)
# Requirement already satisfied: shapely in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from keras-ocr) (2.0.3)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from keras-ocr) (4.66.1)
# Requirement already satisfied: validators in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from keras-ocr) (0.22.0)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from efficientnet==1.0.0->keras-ocr) (1.0.8)
# Requirement already satisfied: scikit-image in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from efficientnet==1.0.0->keras-ocr) (0.22.0)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from imgaug->keras-ocr) (1.16.0)
# Requirement already satisfied: numpy>=1.15 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from imgaug->keras-ocr) (1.23.1)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from imgaug->keras-ocr) (1.10.1)
# Requirement already satisfied: Pillow in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from imgaug->keras-ocr) (9.5.0)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from imgaug->keras-ocr) (3.7.1)
# Requirement already satisfied: opencv-python in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from imgaug->keras-ocr) (4.9.0.80)
# Requirement already satisfied: imageio in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from imgaug->keras-ocr) (2.34.0)
# Requirement already satisfied: h5py in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet==1.0.0->keras-ocr) (3.8.0)
# Requirement already satisfied: networkx>=2.8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->keras-ocr) (3.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->keras-ocr) (2024.2.12)
# Requirement already satisfied: packaging>=21 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->keras-ocr) (23.2)
# Requirement already satisfied: lazy_loader>=0.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->keras-ocr) (0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->imgaug->keras-ocr) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->imgaug->keras-ocr) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->imgaug->keras-ocr) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->imgaug->keras-ocr) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->imgaug->keras-ocr) (2.8.2)
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: pip3.10 install --upgrade pip

# %%
#Importing the library
import matplotlib.pyplot as plt
import keras_ocr
import numpy as np

# keras-ocr will automatically download pretrained
# weights for the detector and recognizer.
pipeline = keras_ocr.pipeline.Pipeline()

# Get a set of three example images
images = [
    keras_ocr.tools.read('sample_waste_report.jpeg')
]

# Each list of predictions in prediction_groups is a list of
# (word, box) tuples.
prediction_groups = pipeline.recognize(images)

# Plot the predictions

fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
axs = axs if isinstance(axs, np.ndarray) else [axs]
for ax, image, predictions in zip(axs, images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image, predictions=predictions, ax=ax)
# Out:
# Looking for /Users/dariuszucker/.keras-ocr/craft_mlt_25k.h5
# Looking for /Users/dariuszucker/.keras-ocr/crnn_kurapan.h5
# 1/1 [==============================] - 7s 7s/step
# 10/10 [==============================] - 15s 1s/step
